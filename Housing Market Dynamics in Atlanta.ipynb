# %% [markdown]
# Housing Market Dynamics in Atlanta
#
#     Locations: Alpharetta, Buckhead, Brookhaven, Decatur, North Druid Hills, Old 4th Ward, Roswell, Sandy Springs, Smyrna, Suwanee

# %% [markdown]
# Project Description/Outline
#
# The housing market has been fluctuating wildly over the past year. We anticipate it will continue to move as early recession signals appear. Our initial goal shall be to deduce: Is 2023 a good time to buy a home?
#
# John Doe’s budget is $500K, we’re guiding him through where and when to buy a home.

# %%
# Dependencies and Setup
#importing functions into jupter notebook
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st

#Creating a path to the data files
atlanta_home_data = "areas_clean.csv"

house_market_df = pd.read_csv(atlanta_home_data)

#display results
house_market_df.head()
# Out:
#    Region Month of Period End Median Sale Price Median Sale Price MoM  \
# 0   30022            2/1/2012          $215,000                -7.90%
# 1   30022            3/1/2012          $212,000                -1.30%
# 2   30022            4/1/2012          $230,000                 8.40%
# 3   30022            5/1/2012          $233,000                 1.30%
# 4   30022            6/1/2012          $239,000                 2.60%
#
#   Median Sale Price YoY  Homes Sold Homes Sold MoM Homes Sold YoY  \
# 0               -12.20%         174         -1.10%          9.40%
# 1               -12.60%         177          1.70%         14.20%
# 2                 4.50%         208         17.50%         16.20%
# 3                 5.90%         231         11.10%         12.10%
# 4                 2.10%         276         19.50%          7.00%
#
#    New Listings New Listings MoM New Listings YoY  Inventory Inventory MoM  \
# 0           246           12.30%          -14.60%        403         0.00%
# 1           318           29.30%          -15.60%        425         5.50%
# 2           360           13.20%           -7.70%        448         5.40%
# 3           401           11.40%           -6.70%        466         4.00%
# 4           396           -1.20%           -2.50%        454        -2.60%
#
#   Inventory YoY  Days on Market  Days on Market MoM  Days on Market YoY  \
# 0       -23.80%              80                 -19               -49.0
# 1       -24.20%              94                  14               -39.0
# 2       -23.40%              86                  -9               -43.0
# 3       -19.90%              77                  -9               -33.0
# 4       -22.10%              62                 -15               -21.0
#
#   Average Sale To List Average Sale To List MoM Average Sale To List YoY
# 0               94.40%                    0.20%                   -0.10%
# 1               94.80%                    0.30%                   -0.30%
# 2               96.10%                    1.40%                    1.30%
# 3               96.30%                    0.20%                    1.30%
# 4               96.10%                   -0.20%                    0.90%

# %% [markdown]
# Where should potential home buyers search for the most affordable home in several price ranges? (low, mid, high) (how much will you pay, any homes to buy, how quickly do you need to buy)

# %%
#median price and compare the inventory or plot the inventory price and compare them together
#line plot? Scatter plot?

# %%
house_market_df['Median Sale Price'] = house_market_df['Median Sale Price'].str.strip('$').str.replace(',','').astype('float')

# %%
#Month of Period End breaking up by the years

# %%
#group by Region
housing_by_region_mean = house_market_df.groupby('Region')['Median Sale Price'].mean()
housing_by_region_median =house_market_df.groupby('Region')['Median Sale Price'].median()
housing_by_region_variance =house_market_df.groupby('Region')['Median Sale Price'].var()
housing_by_region_stdev = house_market_df.groupby('Region')['Median Sale Price'].std()

housing_by_region_summary = pd.DataFrame({"Mean": housing_by_region_mean,'Median': housing_by_region_median, 
                                          'Variance': housing_by_region_variance,'Standard Deviation': housing_by_region_stdev})

housing_by_region_summary
# Out:
#                Mean    Median      Variance  Standard Deviation
# Region
# 30022   362218.7500  348000.0  8.579842e+09        92627.434032
# 30024   338250.0000  330000.0  8.073858e+09        89854.650785
# 30080   281187.5000  277500.0  6.717870e+09        81962.613909
# 30312   282156.2500  286500.0  9.313314e+09        96505.512674
# 30319   469726.5625  459500.0  9.374972e+09        96824.438482
# 30328   337148.4375  335000.0  6.686474e+09        81770.861900
# 30329   338968.7500  340500.0  7.503826e+09        86624.625756
# 30625   325117.1875  322500.0  1.352106e+10       116280.113945

# %%
 house_market_df.describe()
# Out:
#              Region  Median Sale Price   Homes Sold  New Listings  \
# count   1024.000000        1024.000000  1024.000000   1024.000000
# mean   30254.875000      341846.679688   207.776367    243.393555
# std      191.576227      108196.306732   130.260960    154.807850
# min    30022.000000       71000.000000     1.000000      5.000000
# 25%    30066.000000      268000.000000    99.000000    112.750000
# 50%    30315.500000      335000.000000   217.000000    245.500000
# 75%    30328.250000      405000.000000   296.250000    347.000000
# max    30625.000000      800000.000000   599.000000    710.000000
#
#          Inventory  Days on Market  Days on Market MoM  Days on Market YoY
# count  1024.000000     1024.000000         1024.000000         1023.000000
# mean    203.403320       51.454102           -0.686523           -8.503421
# std     136.417931       39.602100           19.831706           30.490891
# min       4.000000        8.000000         -172.000000         -169.000000
# 25%      83.000000       29.750000           -4.000000          -20.000000
# 50%     217.000000       43.000000            0.000000           -7.000000
# 75%     302.000000       59.000000            4.000000            3.000000
# max     593.000000      333.000000          242.000000          178.000000

# %%
#inventory and median sale price
house_market_df.plot('Median Sale Price', 'Inventory',kind='scatter')
# Out:
# <AxesSubplot:xlabel='Median Sale Price', ylabel='Inventory'>

# %%
#different scatter plots for region and see the relationship by year
#scatter plots should roughly look the same 
#groupby region and year
