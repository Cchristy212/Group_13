# %%
# Dependencies and Setup
#importing functions into jupter notebook...new seaborn package
import seaborn

import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
  

#DataFrame Creation
house_market_df = pd.read_csv("areas_clean_final.csv")
house_market_df
# Out:
#       Region Month of Period End Median Sale Price Median Sale Price MoM   \
# 0      30022              Feb-22         $215,000                  -7.90%
# 1      30022              Mar-22         $212,000                  -1.30%
# 2      30022              Apr-22         $230,000                   8.40%
# 3      30022              May-22         $233,000                   1.30%
# 4      30022              Jun-22         $239,000                   2.60%
# ...      ...                 ...               ...                    ...
# 1019   30625              May-22         $393,000                   9.80%
# 1020   30625              Jun-22         $423,000                   7.60%
# 1021   30625              Jul-22         $423,000                   0.00%
# 1022   30625              Aug-22         $800,000                  89.30%
# 1023   30625              Sep-22         $760,000                  -5.00%
#
#      Median Sale Price YoY   Homes Sold Homes Sold MoM  Homes Sold YoY   \
# ...

# %%
house_market_df['Median Sale Price'] = house_market_df['Median Sale Price'].str.strip('$').str.replace(',','').astype('float')

# %%
# pairplot based on column we choose for color scheme...will try Region
seaborn.pairplot(house_market_df,hue = 'Region')
# to show
plt.show()

# %%
house_market_df.corr()
# Out:
#                       Region  Median Sale Price  Homes Sold  New Listings  \
# Region              1.000000           0.028586   -0.801742     -0.769079
# Median Sale Price   0.028586           1.000000    0.177396      0.134965
# Homes Sold         -0.801742           0.177396    1.000000      0.937816
# New Listings       -0.769079           0.134965    0.937816      1.000000
# Inventory          -0.671665          -0.114685    0.781690      0.849334
# Days on Market      0.469361          -0.346852   -0.435069     -0.398315
# Days on Market MoM -0.008603           0.033298    0.002485     -0.047753
# Days on Market YoY -0.011169           0.092914    0.017996      0.024785
#
#                     Inventory  Days on Market  Days on Market MoM  \
# Region              -0.671665        0.469361           -0.008603
# Median Sale Price   -0.114685       -0.346852            0.033298
# Homes Sold           0.781690       -0.435069            0.002485
# ...

# %%
#Homes sold in month/Available properties for sale = Months of Inventory..

# Create a new column that computes this
mons_inventory = house_market_df['Homes Sold'] / house_market_df['Inventory']
mons_inventory
